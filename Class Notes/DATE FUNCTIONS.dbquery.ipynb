-- %%
-- CLASS NOTES
04/06/2026
DATE FUNCTIONS


SELECT current_date() AS today_dt;

-- CURRENT_DATE()
SELECT current_date() As today_dt; -- This function give us today's date
SELECT current_date()-1 As yesterday_dt; -- This fuction gives me yesterday's date because i put a minus 1

-- CURRENT_TIMESTAMP()
SELECT current_timestamp() AS datetime; -- This function is used to get the current date and time 

-- TO_DATE(string, format) - Converts a string(text/words) to a date 
SELECT to_date('20260603', 'yyyyMMdd') AS dt;

SELECT try_to_date('03 June 2026', 'dd MMMM yyyy') AS dt;

-- TO_CHAR(expr,fmt)/date_format(): Convert a date into a string(text)
SELECT  current_date() AS today_dt,
        year(current_date()) as year,
        month(current_date()) as month,
        monthname(current_date()) as month_name,
        date_format(current_date(), 'yyyyMM') AS month_id;

-- Converting to your timezone
SELECT convert_timezone('UTC', 'GMT+2', current_timestamp()) AS datetime;

-- DATEDIFF(end_date,start_date) - we use this function to calculate the difference between two dates
SELECT datediff(current_date(), current_date()-3);

-- Date_sub(date, number of days) - it subtracts the number of days from your date column
SELECT date_sub(current_date(), 2) AS trans_dt; 

-- Date_add(date, number of days) - it adds the number of days from the date column
SELECT date_add(to_date('2026-01-01'),5) AS break_up_dt;


-- CURRENT_DATE()
SELECT current_date() As today_dt; -- This function give us today's date
SELECT current_date()-1 As yesterday_dt; -- This fuction gives me yesterday's date because i put a minus 1

-- CURRENT_TIMESTAMP()
SELECT current_timestamp() AS datetime; -- This function is used to get the current date and time 

-- TO_DATE(string, format) - Converts a string(text/words) to a date 
SELECT to_date('20260603', 'yyyyMMdd') AS dt;

SELECT try_to_date('03 June 2026', 'dd MMMM yyyy') AS dt;

-- TO_CHAR(expr,fmt)/date_format(): Convert a date into a string(text)
SELECT  current_date() AS today_dt,
        year(current_date()) as year,
        month(current_date()) as month,
        monthname(current_date()) as month_name,
        date_format(current_date(), 'yyyyMM') AS month_id;

-- Converting to your timezone
SELECT convert_timezone('UTC', 'GMT+2', current_timestamp()) AS datetime;

-- DATEDIFF(end_date,start_date) - we use this function to calculate the difference between two dates
SELECT datediff(current_date(), current_date()-3);

-- Date_sub(date, number of days) - it subtracts the number of days from your date column
SELECT date_sub(current_date(), 2) AS trans_dt; 

-- Date_add(date, number of days) - it adds the number of days from the date column
SELECT date_add(to_date('2026-01-01'),5) AS break_up_dt;


--- MY PRACTICE ON DATE FUNCTIONS

SELECT current_date(); -- Output will be today's date

SELECT current_date(),
        YEAR(current_date()) AS current_year, -- extract the year from current date
        DAY(current_date()) AS current_day, -- extract the day of the month from current date
        MONTH(current_date()) AS current_month, -- extract the month of the year from the current date
        MONTHNAME(current_date()) AS cur_mnth, -- extract the month of the year from the current date and writes it in words
        DAYNAME(current_date()) AS cur_day, --extract the day of the week from the current date and writes it into words
        current_timestamp; --gives you the time according to the set timezone


SELECT date_add(current_date(),2); -- date, 2 days from now

SELECT date_add(current_date(),2) AS future_date, -- date, 2 days from now
        DAY(date_add(current_date(),2)) AS future_day, --extract day of month, 2 days from now
        DAYNAME(date_add(current_date(),2)) AS dayofweek_future, -- extract day of the week, 2 days from now
        MONTHNAME(date_add(current_date(),2)) AS monthname_future, -- extract month name and write it to words, 2 days from now
        YEAR(date_add(current_date(),2)) AS year_future; -- extract year, 2 days from now


SELECT date_sub(current_date(),3); -- Date, 3 days ago.

SELECT date_sub(current_date(),3) AS past_date, --Date, 3 days ago.

        DAY(date_sub(current_date(),3)) AS past_day, -- Day of the month, 3 days ago
        DAYNAME(date_sub(current_date(),3)) AS dayofweek_past, -- day of the week, in words, 3 days ago
        MONTHNAME(date_sub(current_date(),3)) AS monthname_past,-- month of the year, in words, 3 days ago
        YEAR(date_sub(current_date(),3)) AS year_past; -- year, 3 days ago


SELECT date_diff('2026-06-04','2026-05-01');-- gives you the difference between two dates.
-- There are 34 days between the two dates.


SELECT date_format(Current_date(),'MM/yyyy/dd'); -- When you wish to format the date to your desired preference.

SELECT date_format(current_date(), 'dd-MM-yyyy') AS formated_date;

-- I kept getting the output as '2026-00-04' because I used this format: 'yyyy-mm-dd'.
-- I learned that 'mm' is intepreted as minutes and
-- 'MM' = month

-- | Format | Meaning            | Example  |
| ------ | ------------------ | -------- |
| `dd`   | Day of month       | 04       |
| `MM`   | Month number       | 06       |
| `MMM`  | Month abbreviation | Jun      |
| `MMMM` | Full month name    | June     |
| `yy`   | 2-digit year       | 26       |
| `yyyy` | 4-digit year       | 2026     |
| `E`    | Day abbreviation   | Thu      |
| `EEEE` | Full day name      | Thursday |
| `mm`   | Minutes            | 00       |


SELECT date_format(current_date(), 'EEEE, dd MMMM yyyy');

SELECT DATE('2026-05-04') AS sales_date,
        datediff(current_date(),sales_date) AS date_no;

SELECT DATE ('2026-03-05') AS sales_date,
        date_format('sales_date', 'DD-MM-YYYY');

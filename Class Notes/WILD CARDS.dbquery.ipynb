-- %%
10 JUNE 2026
---- CLASS NOTES:

SELECT *
FROM workspace.default.bright_coffee;

SELECT STORE_LOCATION,
    product_category
FROM workspace.default.bright_coffee
where product_category ILIKE 'TEA'
LIMIT 1000;
------------------------------------------------
SELECT transaction_date,
       store_location
FROM workspace.default.bright_coffee
WHERE store_location LIKE 'A%';
-------------------------------------------------
SELECT transaction_date,
       store_location
FROM workspace.default.bright_coffee
WHERE store_location ILIKE 'a%';
-------------------------------------------------
-- LIKE : It is case sensetive 
-- ILIKE : It is not case sensetive 
-------------------------------------------------
select*from workspace.default.bright_coffee limit 10;

SELECT DISTINCT day_name
FROM workspace.default.bright_coffee
WHERE day_name ILIKE 'S%';

SELECT revenue
FROM workspace.default.bright_coffee
WHERE revenue LIKE '2%';


--------------------------------------
---- PRACTICE

SELECT Date, `Product Category`
FROM retail.sales.retail_sales_dataset
WHERE `Product Category` LIKE 'B%'; --- I want the product category that starts with a 'B'. I used  LIKE because the values in the table are case sensitive.
--- The outcome is BEAUTY.

SELECT `Product Category`, gender
from retail.sales.retail_sales_dataset
WHERE `Product Category` ilike '%y'; --- I want values where the product category that ends with a 'y'. I used ILIKE because I don't want ant confusion with case sensitiveness. The iutcome is BEAUTY.

SELECT `Product Category`, gender
from retail.sales.retail_sales_dataset
WHERE gender ilike '__male'; --- I want the gender which has 2 letters in front, and ends with 'male'. The outcome is FEMALE. The underscore limits the outcome to only have 2 letters before 'male'.

SELECT *
from retail.sales.retail_sales_dataset
LIMIT 1;

SELECT `Product Category`, gender, age
from retail.sales.retail_sales_dataset
WHERE age ilike '2%'; ---- the ages all have the value '2' in front

SELECT `Product Category`, gender, age
from retail.sales.retail_sales_dataset
WHERE age ilike '_0'; --- the value of the age should end with a zero.
